# %% [markdown]
# PROJECT-9:Heart Disease Dataset

# %% [markdown]
# 1. Import The Libraries And Dataset

# %%
#import libarires
import pandas as pd
import matplotlib.pyplot as plt

# %%
#IMPORT DATA SET
import pandas as pd
df=pd.read_csv(r"C:\Users\gnane\Downloads\data set python projects\heart.csv")
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %% [markdown]
# 2. Display Top 5 Rows of The Dataset

# %%
df.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# About this file
#
# Suggest Edits
# Attribute Information:
#
# age
# sex
# chest pain type (4 values)
# resting blood pressure
# serum cholestoral in mg/dl
# fasting blood sugar > 120 mg/dl
# resting electrocardiographic results (values 0,1,2)
# maximum heart rate achieved
# exercise induced angina
# oldpeak = ST depression induced by exercise relative to rest
# the slope of the peak exercise ST segment
# number of major vessels (0-3) colored by flourosopy
# thal: 0 = normal; 1 = fixed defect; 2 = reversable defect

# %% [markdown]
# 3. Check The Last 5 Rows of The Dataset

# %%
df.tail(5)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %% [markdown]
# 4. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
df.shape
# Out:
# (1025, 14)

# %%
print('no of rows',df.shape[0])# rows wise
# Out:
# no of rows 1025

# %%
print('No of columns',df.shape[1])
# Out:
# No of columns 14

# %% [markdown]
# 5. Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %% [markdown]
# 6. Check Null Values In The Dataset

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
#visual repersrntation
import seaborn as sns
sns.heatmap(df.isnull()) # there is no null values in our data set
# Out:
# <Axes: >

# %% [markdown]
# 7. Check For Duplicate Data and Drop Them

# %%
# Check for duplicate rows in entire DataFrame
df.duplicated().sum()
# Out:
# np.int64(723)

# %%
# Show all duplicate rows
df[df.duplicated()].sum()
# Out:
# age          39360.0
# sex            507.0
# cp             675.0
# trestbps     95158.0
# chol        177707.0
# fbs            108.0
# restecg        384.0
# thalach     107672.0
# exang          246.0
# oldpeak        783.3
# slope          998.0
# ca             556.0
# thal          1683.0
# target         362.0
# dtype: float64

# %%
# drop the duplicate values
# Drop all duplicate rows
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (302, 14)

# %% [markdown]
# 8. Get Overall Statistics About The Dataset

# %%
df.describe()# only numerical values
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
df.describe(include='all')
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %% [markdown]
# 9. Draw Correlation Matrix

# %%
df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.103240 -0.071966  0.271121  0.219823  0.121243
# sex      -0.103240  1.000000 -0.041119 -0.078974 -0.198258  0.027200
# cp       -0.071966 -0.041119  1.000000  0.038177 -0.081641  0.079294
# trestbps  0.271121 -0.078974  0.038177  1.000000  0.127977  0.181767
# chol      0.219823 -0.198258 -0.081641  0.127977  1.000000  0.026917
# fbs       0.121243  0.027200  0.079294  0.181767  0.026917  1.000000
# restecg  -0.132696 -0.055117  0.043581 -0.123794 -0.147410 -0.104051
# thalach  -0.390227 -0.049365  0.306839 -0.039264 -0.021772 -0.008866
# exang     0.088163  0.139157 -0.401513  0.061197  0.067382  0.049261
# oldpeak   0.208137  0.084687 -0.174733  0.187434  0.064880  0.010859
# slope    -0.169105 -0.026666  0.131633 -0.120445 -0.014248 -0.061902
# ca        0.271551  0.111729 -0.176206  0.104554  0.074259  0.137156
# thal      0.072297  0.198424 -0.163341  0.059276  0.100244 -0.042177
# ...

# %%
# for visual 
import seaborn as sns
plt.figure(figsize=(17,6))  # Bigger figure size
sns.heatmap(df.corr(),annot=True)
plt.title('Correlation Heatmap', fontsize=30)
plt.show()

# %% [markdown]
# 10. How Many People Have Heart Disease, And How Many Don't Have Heart Disease In This Dataset?

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df['target'].value_counts()
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %%
sns.countplot(x='target', data=df, palette='Set2')
# Out:
# C:\Users\gnane\AppData\Local\Temp\ipykernel_16484\2358493125.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='target', data=df, palette='Set2')
# <Axes: xlabel='target', ylabel='count'>

# %%
# for full strucure code
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
sns.countplot(x='target', data=df, palette='Set2')  # or any palette
plt.title('Distribution of Target Variable')
plt.xlabel('Target')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\gnane\AppData\Local\Temp\ipykernel_16484\3199671655.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='target', data=df, palette='Set2')  # or any palette

# %% [markdown]
# 11. Find Count of  Male & Female in this Dataset

# %%
df['sex'].value_counts()
# Out:
# sex
# 1    713
# 0    312
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x='sex',data=df,palette=['red','green'])
plt.xticks(ticks=[0,1], labels=['Female','Male']) 
plt.show()
# Out:
# C:\Users\gnane\AppData\Local\Temp\ipykernel_16484\2121654447.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex',data=df,palette=['red','green'])

# %% [markdown]
# 12. Find Gender Distribution According to The Target Variable

# %%
sns.countplot(x='sex',hue='target',data=df,palette=['orange','red'])
plt.xticks(ticks=[0,1],labels=['Female','Male'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# 13. Check Age Distribution In The Dataset

# %%
sns.histplot(df['age'], bins=20, kde=True, color='red')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# 14. Check Chest Pain Type

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='cp', data=df,palette=['green','orange','red','blue'])
plt.title("Count of CP values")
plt.show()
# Out:
# C:\Users\gnane\AppData\Local\Temp\ipykernel_23916\3526268438.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='cp', data=df,palette=['green','orange','red','blue'])

# %% [markdown]
# 15. Show The Chest Pain Distribution As Per Target Variable

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='cp', hue='target', data=df)
plt.legend(labels=['no disease', 'disease'])
plt.title("Count of CP by Target")
plt.show()

# %% [markdown]
# 16. Show Fasting Blood Sugar Distribution According To Target Variable

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='fbs', hue='target', data=df)
plt.legend(labels=['no disease', 'disease'])
plt.title("Count of CP by Target")
plt.show()

# %% [markdown]
# 17.  Check Resting Blood Pressure Distribution

# %%
df['trestbps'].hist()
# Out:
# <Axes: >

# %% [markdown]
# 18. Compare Resting Blood Pressure As Per Sex Column

# %%
g=sns.FacetGrid(df,hue='sex',aspect=4)
g.map(sns.kdeplot,'trestbps',shade=True)
plt.legend(labels=['Male','Female'])
# Out:
# C:\Users\gnane\AppData\Roaming\Python\Python313\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\gnane\AppData\Roaming\Python\Python313\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)

# %% [markdown]
# 19. Show Distribution of Serum cholesterol

# %%
df['chol'].hist()
# Out:
# <Axes: >

# %% [markdown]
# 20. Plot Continuous Variables

# %%
cate_value=[]
count_value=[]
for column in df.columns:
    if df[column].nunique() <=10:
        cate_value.append(column)
    else:count_value.append(column)

# %%
cate_value# categorial values
# Out:
# ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'target']

# %%
count_value # continous values
# Out:
# ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

# %%
plt.figure(figsize=(15,6))
plt.tight_layout()
df.hist(count_value)
plt.show()
